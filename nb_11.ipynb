# %% [markdown]
# <a href="https://colab.research.google.com/github/kyochanpy/forest_bears/blob/main/nb_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/cart_log.csv')

# %%
df
# Out:
#                                               session_id  ...  created_at__hour
# 0      00003ee1b7f34620ae81dba533c6d5a544513004fe5688...  ...              11.0
# 1      00003ee1b7f34620ae81dba533c6d5a544513004fe5688...  ...              11.0
# 2      00003ee1b7f34620ae81dba533c6d5a544513004fe5688...  ...              11.0
# 3      00003ee1b7f34620ae81dba533c6d5a544513004fe5688...  ...              11.0
# 4      00003ee1b7f34620ae81dba533c6d5a544513004fe5688...  ...              11.0
# ...                                                  ...  ...               ...
# 30765  044b61bb01999d8960bcbea6f91f9557a06d9c378ca1c8...  ...              16.0
# 30766  044c45825dc0158f2d74ca267ea42fb5991b873d695746...  ...              19.0
# 30767  044c45825dc0158f2d74ca267ea42fb5991b873d695746...  ...              20.0
# 30768  044c45825dc0158f2d74ca267ea42fb5991b873d695746...  ...              20.0
# 30769  044c45825dc0158f2d74ca267ea42fb5991b873d695746...  ...               NaN
#
# ...

# %%
# !unzip /content/atmaCup13_dataset.zip -d /content/drive/MyDrive/atma_13
# Out:
# Archive:  /content/atmaCup13_dataset.zip
# warning [/content/atmaCup13_dataset.zip]:  1048576 extra bytes at beginning or within zipfile
#   (attempting to process anyway)
# file #1:  bad zipfile offset (local header sig):  1048576
#   (attempting to re-compensate)
# replace /content/drive/MyDrive/atma_13/coupon.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: /content/drive/MyDrive/atma_13/coupon.csv
# error: not enough memory for bomb detection

# %%
y
# !pip uninstall -qy kaggle
# !pip install -Uq kaggle
# !apt-get install -y p7zip-full tree
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# p7zip-full is already the newest version (16.02+dfsg-6).
# tree is already the newest version (1.7.0-5).
# The following packages were automatically installed and are no longer required:
#   cuda-command-line-tools-10-0 cuda-command-line-tools-10-1
#   cuda-command-line-tools-11-0 cuda-compiler-10-0 cuda-compiler-10-1
#   cuda-compiler-11-0 cuda-cuobjdump-10-0 cuda-cuobjdump-10-1
#   cuda-cuobjdump-11-0 cuda-cupti-10-0 cuda-cupti-10-1 cuda-cupti-11-0
#   cuda-cupti-dev-11-0 cuda-documentation-10-0 cuda-documentation-10-1
#   cuda-documentation-11-0 cuda-documentation-11-1 cuda-gdb-10-0 cuda-gdb-10-1
#   cuda-gdb-11-0 cuda-gpu-library-advisor-10-0 cuda-gpu-library-advisor-10-1
#   cuda-libraries-10-0 cuda-libraries-10-1 cuda-libraries-11-0
#   cuda-memcheck-10-0 cuda-memcheck-10-1 cuda-memcheck-11-0 cuda-nsight-10-0
# ...

# %%
# %%writefile /root/.kaggle/kaggle.json
# {"username":"kyochanpy","key":"2716571e965bd0268361ed38e3a4eb79"}
# Out:
# Overwriting /root/.kaggle/kaggle.json

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !mkdir -p /content/drive/MyDrive/H_and_M

# %%
# !kaggle competitions download -c h-and-m-personalized-fashion-recommendations -p /content/drive/MyDrive/H_and_M
# Out:
# ...
# 100% 28.7G/28.7G [03:59<00:00, 137MB/s]
# 100% 28.7G/28.7G [03:59<00:00, 129MB/s]

# %%
! unzip /content/drive/MyDrive/H_and_M/h-and-m-personalized-fashion-recommendations.zip && rm /content/drive/MyDrive/H_and_M/h-and-m-personalized-fashion-recommendations.zip
# Out:
# Archive:  /content/drive/MyDrive/H_and_M/h-and-m-personalized-fashion-recommendations.zip
# replace articles.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: articles.csv
# replace customers.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: customers.csv           y
#
# replace images/010/0108775015.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:   inflating: images/010/0108775015.jpg
# replace images/010/0108775044.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: images/010/0108775044.jpg
# replace images/010/0108775051.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# !unzip /content/drive/MyDrive/H_and_M/h-and-m-personalized-fashion-recommendations.zip -d /content/drive/MyDrive/H_and_M
# Out:
# Archive:  /content/drive/MyDrive/H_and_M/h-and-m-personalized-fashion-recommendations.zip
# replace /content/drive/MyDrive/H_and_M/articles.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: /content/drive/MyDrive/H_and_M/articles.csv
# replace /content/drive/MyDrive/H_and_M/customers.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: /content/drive/MyDrive/H_and_M/customers.csv
# replace /content/drive/MyDrive/H_and_M/images/010/0108775015.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: /content/drive/MyDrive/H_and_M/images/010/0108775015.jpg
# replace /content/drive/MyDrive/H_and_M/images/010/0108775044.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: /content/drive/MyDrive/H_and_M/images/010/0108775044.jpg
# replace /content/drive/MyDrive/H_and_M/images/010/0108775051.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: /content/drive/MyDrive/H_and_M/images/010/0108775051.jpg
# y
# ...

# %%
y!chmod 600 /root/.kaggle/kaggle.json
# !mkdir -p /kaggle/input/indoor-location-navigation
# !kaggle competitions download -c indoor-location-navigation -p /kaggle/input/indoor-location-navigation
